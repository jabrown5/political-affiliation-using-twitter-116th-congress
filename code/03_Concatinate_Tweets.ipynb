# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Importing the merged Tweets DF
data = pd.read_csv('../data/cleaned_df.csv')

# %%
data.head()
# Out:
#              id  screen_name             user_id                       time  \
# 0  1.003033e+18  RepBarragan  816833925456789504  2018-06-02T17:55:58-04:00
# 1  1.002996e+18  RepBarragan  816833925456789504  2018-06-02T15:30:27-04:00
# 2  1.002620e+18  RepBarragan  816833925456789504  2018-06-01T14:38:33-04:00
# 3  1.002744e+18  RepBarragan  816833925456789504  2018-06-01T22:49:51-04:00
# 4  1.002744e+18  RepBarragan  816833925456789504  2018-06-01T22:50:17-04:00
#
#                                                 link  \
# 0  https://www.twitter.com/RepBarragan/statuses/1...
# 1  https://www.twitter.com/RepBarragan/statuses/1...
# 2  https://www.twitter.com/RepBarragan/statuses/1...
# 3  https://www.twitter.com/POLITICOPress/statuses...
# 4  https://www.twitter.com/RepJayapal/statuses/10...
#
#                                                 text              source  \
# 0  So great to welcome @SenSanders to #CA44 for a...  Twitter for iPhone
# 1  In Carson with @SenSanders, @Teamsters, and co...  Twitter for iPhone
# 2  Yesterday, immigrant rights advocates &amp; at...  Twitter for iPhone
# 3  RT @POLITICOPress Next week is our FIRST #Wome...  Twitter for iPhone
# 4  RT @RepJayapal We (62 members of the House) ar...  Twitter for iPhone
#
#   state        position              name party  congress
# 0    CA  Representative  Nanette Barragan     D       115
# 1    CA  Representative  Nanette Barragan     D       115
# 2    CA  Representative  Nanette Barragan     D       115
# 3    CA  Representative  Nanette Barragan     D       115
# 4    CA  Representative  Nanette Barragan     D       115

# %%
# Counting the number of tweets from each rep / senator
data_grouped = data.groupby(['screen_name'])['id'].count().reset_index()
# renaming column to tweet_count for clarity
data_grouped.rename(columns={'id': 'tweet_count'}, inplace=True)

# %%
# sorting the tweet count df by number of tweets to get the top 5 most prolific tweeters
data_grouped.sort_values(by=['tweet_count'], ascending=False)[:5]
# Out:
#         screen_name  tweet_count
# 203     RepDonBeyer        18325
# 57       JohnCornyn        17369
# 100  RepAndyBiggsAZ        14878
# 208  RepDwightEvans        12698
# 62      LacyClayMO1        10380

# %%
# merging the tweet count df back onto the main df
df = pd.merge(data, data_grouped, on='screen_name', how='outer')

# %%
# confirming that merge was successful
print(f'Pre-tweet count merge size: {data.shape}')
print(f'Post-tweet count merge size: {df.shape}')
# Out:
# Pre-tweet count merge size: (1492855, 12)
# Post-tweet count merge size: (1492855, 13)

# %%
# checking to see that counts match up w/ new df
# counting the number of rows for each user
df['screen_name'].value_counts(ascending=False)[:5]

# the tweet count from 'data_grouped' above matches the number 
# of rows in the larger df
# Out:
# RepDonBeyer       18325
# JohnCornyn        17369
# RepAndyBiggsAZ    14878
# RepDwightEvans    12698
# LacyClayMO1       10380
# Name: screen_name, dtype: int64

# %%
df_text_concat = df.groupby(['screen_name']).agg({'text': ' '.join})

df_text_concat.rename(columns={'text': 'text_concat'}, inplace=True)

df_text_concat.head()
# Out:
#                                                        text_concat
# screen_name
# AnthonyBrownMD4  Congratulations @AmyMcGrathKY Let’s bring it h...
# AustinScottGA08  RT @AustinScottGA08 The summer months are some...
# BennieGThompson  Once again, your hard earned dollars are being...
# BettyMcCollum04  And if you’re looking to provide help, here’s ...
# BillCassidy      Today's jobs report says "the unemployment rat...

# %%
# checking concatinated string length to see that text has been combined
df_text_concat['text_length'] = df_text_concat['text_concat'].apply(len)

df_text_concat.head()
# Out:
#                                                        text_concat  \
# screen_name
# AnthonyBrownMD4  Congratulations @AmyMcGrathKY Let’s bring it h...
# AustinScottGA08  RT @AustinScottGA08 The summer months are some...
# BennieGThompson  Once again, your hard earned dollars are being...
# BettyMcCollum04  And if you’re looking to provide help, here’s ...
# BillCassidy      Today's jobs report says "the unemployment rat...
#
#                  text_length
# screen_name
# AnthonyBrownMD4        19890
# AustinScottGA08       309793
# BennieGThompson       516881
# BettyMcCollum04      1043220
# BillCassidy           620101

# %%
# merging the concatinated text column back onto the larger df
df = pd.merge(df, df_text_concat, on='screen_name', how='outer')

# confirming no lost data by examining shape of data frame
df.shape
# Out:
# (1492855, 15)

# %%
df.head()
# Out:
#              id  screen_name             user_id                       time  \
# 0  1.003033e+18  RepBarragan  816833925456789504  2018-06-02T17:55:58-04:00
# 1  1.002996e+18  RepBarragan  816833925456789504  2018-06-02T15:30:27-04:00
# 2  1.002620e+18  RepBarragan  816833925456789504  2018-06-01T14:38:33-04:00
# 3  1.002744e+18  RepBarragan  816833925456789504  2018-06-01T22:49:51-04:00
# 4  1.002744e+18  RepBarragan  816833925456789504  2018-06-01T22:50:17-04:00
#
#                                                 link  \
# 0  https://www.twitter.com/RepBarragan/statuses/1...
# 1  https://www.twitter.com/RepBarragan/statuses/1...
# 2  https://www.twitter.com/RepBarragan/statuses/1...
# 3  https://www.twitter.com/POLITICOPress/statuses...
# 4  https://www.twitter.com/RepJayapal/statuses/10...
#
#                                                 text              source  \
# 0  So great to welcome @SenSanders to #CA44 for a...  Twitter for iPhone
# 1  In Carson with @SenSanders, @Teamsters, and co...  Twitter for iPhone
# 2  Yesterday, immigrant rights advocates &amp; at...  Twitter for iPhone
# 3  RT @POLITICOPress Next week is our FIRST #Wome...  Twitter for iPhone
# 4  RT @RepJayapal We (62 members of the House) ar...  Twitter for iPhone
#
#   state        position              name party  congress  tweet_count  \
# 0    CA  Representative  Nanette Barragan     D       115         4553
# 1    CA  Representative  Nanette Barragan     D       115         4553
# 2    CA  Representative  Nanette Barragan     D       115         4553
# 3    CA  Representative  Nanette Barragan     D       115         4553
# 4    CA  Representative  Nanette Barragan     D       115         4553
#
#                                          text_concat  text_length
# 0  So great to welcome @SenSanders to #CA44 for a...      1571519
# 1  So great to welcome @SenSanders to #CA44 for a...      1571519
# 2  So great to welcome @SenSanders to #CA44 for a...      1571519
# 3  So great to welcome @SenSanders to #CA44 for a...      1571519
# 4  So great to welcome @SenSanders to #CA44 for a...      1571519

# %%
# dropping duplicates as we only need concatinated text column for purposes of future analyses
# df = df.drop_duplicates(subset=None, keep='first')

df = df.drop_duplicates(['screen_name'], keep='last')


print(df.shape)
print('----------')
df.head()
# Out:
# (626, 15)
# ----------
#                  id     screen_name             user_id  \
# 4552   1.268317e+18     RepBarragan  816833925456789504
# 13345  1.268363e+18   ChrisMurphyCT           150078976
# 19186  1.268304e+18     RepSwalwell           942156122
# 37511  1.268352e+18     RepDonBeyer          2962868158
# 40677  1.268379e+18  WarrenDavidson  742735530287304704
#
#                             time  \
# 4552   2020-06-03T19:00:18-04:00
# 13345  2020-06-03T22:03:29-04:00
# 19186  2020-06-03T18:10:04-04:00
# 37511  2020-06-03T21:20:23-04:00
# 40677  2020-06-03T23:10:01-04:00
#
#                                                     link  \
# 4552   https://www.twitter.com/RepBarragan/statuses/1...
# 13345  https://www.twitter.com/ChrisMurphyCT/statuses...
# 19186  https://www.twitter.com/yashar/statuses/126830...
# 37511  https://www.twitter.com/RepDonBeyer/statuses/1...
# 40677  https://www.twitter.com/WarrenDavidson/statuse...
#
#                                                     text              source  \
# 4552   The murder of #GeorgeFloyd by police was anoth...     Twitter Web App
# 13345  The blame for the lack of federal leadership o...     Twitter Web App
# 19186  RT @yashar James Mattis Denounces President Tr...  Twitter for iPhone
# 37511  Calling for military violence against American...  Twitter for iPhone
# 40677  Heaven is diverse. \nRevelation 7:9-12 http://...  Twitter for iPhone
#
#       state        position                   name party  congress  \
# 4552     CA  Representative  Nanette Diaz Barrag_n     D       116
# 13345    CT         Senator     Christopher Murphy     D       116
# 19186    CA  Representative          Eric Swalwell     D       116
# 37511    VA  Representative        Donald Beyer Jr     D       116
# 40677    OH  Representative        Warren Davidson     R       116
#
#        tweet_count                                        text_concat  \
# 4552          4553  So great to welcome @SenSanders to #CA44 for a...
# 13345         8793  New apartments, new businesses and new restaur...
# 19186         5841  Literally, the easiest fix we could make to sa...
# 37511        18325  9 Baltimore students were killed with guns dur...
# 40677         3166  #NetNeutrality Reminder: Obama used 1934 FCC r...
#
#        text_length
# 4552       1571519
# 13345      2801192
# 19186      1843540
# 37511      7087050
# 40677       958737

# %%
# dropping extra columns
df = df.drop(['id', 'user_id', 'time', 'link', 'text', 'source', 'congress'], axis = 1)

print(df.shape)
print('----------')
df.head()
# Out:
# (626, 8)
# ----------
#           screen_name state        position                   name party  \
# 4552      RepBarragan    CA  Representative  Nanette Diaz Barrag_n     D
# 13345   ChrisMurphyCT    CT         Senator     Christopher Murphy     D
# 19186     RepSwalwell    CA  Representative          Eric Swalwell     D
# 37511     RepDonBeyer    VA  Representative        Donald Beyer Jr     D
# 40677  WarrenDavidson    OH  Representative        Warren Davidson     R
#
#        tweet_count                                        text_concat  \
# 4552          4553  So great to welcome @SenSanders to #CA44 for a...
# 13345         8793  New apartments, new businesses and new restaur...
# 19186         5841  Literally, the easiest fix we could make to sa...
# 37511        18325  9 Baltimore students were killed with guns dur...
# 40677         3166  #NetNeutrality Reminder: Obama used 1934 FCC r...
#
#        text_length
# 4552       1571519
# 13345      2801192
# 19186      1843540
# 37511      7087050
# 40677       958737

# %%
# resetting the index
df.reset_index(inplace = True)

# need this line other wise index column will be created
# w/ old index values.
df.drop(['index'], axis = 1, inplace = True)

df.head()
# Out:
#       screen_name state        position                   name party  \
# 0     RepBarragan    CA  Representative  Nanette Diaz Barrag_n     D
# 1   ChrisMurphyCT    CT         Senator     Christopher Murphy     D
# 2     RepSwalwell    CA  Representative          Eric Swalwell     D
# 3     RepDonBeyer    VA  Representative        Donald Beyer Jr     D
# 4  WarrenDavidson    OH  Representative        Warren Davidson     R
#
#    tweet_count                                        text_concat  text_length
# 0         4553  So great to welcome @SenSanders to #CA44 for a...      1571519
# 1         8793  New apartments, new businesses and new restaur...      2801192
# 2         5841  Literally, the easiest fix we could make to sa...      1843540
# 3        18325  9 Baltimore students were killed with guns dur...      7087050
# 4         3166  #NetNeutrality Reminder: Obama used 1934 FCC r...       958737

# %%
# Exporting the cleaned and concatinated dataframe
export_df = df.to_csv('../data/concat_df.csv', index = False)
